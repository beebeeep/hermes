# %%
# %matplotlib notebook

import hermes
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
agents = hermes.model(500, 0.1, 5000)
# Out:
# Day 4999 finished, 947 transactions.

# %%
money = [x.money for x in agents]
d = pd.DataFrame(money)

# %%
z=pd.DataFrame.hist(d, bins=50)
# Out:
# <img src="data:image/png;base64,...">
